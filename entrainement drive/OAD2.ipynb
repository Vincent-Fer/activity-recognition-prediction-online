# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import os
print("Tensorflow version " + tf.__version__)

resolver = tf.distribute.cluster_resolver.TPUClusterResolver('grpc://' + os.environ['COLAB_TPU_ADDR'])
tf.config.experimental_connect_to_cluster(resolver)

# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))

strategy = tf.distribute.TPUStrategy(resolver)
# Out:
# Tensorflow version 2.8.0
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: grpc://10.112.33.250:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.112.33.250:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %%
import numpy as np
import keras
import time
import tensorflow as tf
from keras.callbacks import ModelCheckpoint, EarlyStopping,Callback
from keras.layers import Dense,Reshape,Input,BatchNormalization,Dropout,concatenate,Flatten,Lambda,Resizing,CuDNNLSTM,concatenate,Layer,LSTM
from keras import  Model,layers
from tensorflow.keras.applications import VGG16
from sklearn.model_selection import train_test_split

# %%
def find_removable(n,batch_size=64):
      return n%batch_size

# %%
base_path = '/content/drive/MyDrive/Colab Notebooks/OAD/OAD/Vincent/BASE/30/'
# base_path = '/content/drive/MyDrive/Colab Notebooks/NTU/Vincent/ntu_3cam/'
input_shape= (25,30, 3)

train_x = np.load(base_path+'train_x.npy')
test_x = np.load(base_path+'test_x.npy')
train_y = np.load(base_path+'train_y.npy')
test_y = np.load(base_path+'test_y.npy')

batch_size=64

n = find_removable(len(train_x),batch_size)
train_x = train_x[:-n]
train_y = train_y[:-n]

print('lost',n)

train = (train_x,train_y)
test = (test_x,test_y)
# Out:
# lost 31

# %%
with strategy.scope(): # creating the model in the TPUStrategy scope means we will train the model on the TPU
  inp=Input(np.asarray(input_shape))
  output = Resizing(64, 64)(inp)
  model = VGG16(include_top=False,input_shape=(64,64,3))
  for layer in model.layers:
      layer.trainable = True
  output = model(output)
  output = Flatten()(output)
  output = Dense(2048)(output)
  output = BatchNormalization()(output)
  output = Dense(10, activation='softmax',kernel_regularizer='l1')(output)
  model = Model(inp, output)
  model.summary()
  optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
  model.compile(loss=keras.losses.categorical_crossentropy,
                optimizer=optimizer,
                metrics=['accuracy'])
# Out:
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_40 (InputLayer)       [(None, 25, 30, 3)]       0
#
#  resizing_20 (Resizing)      (None, 64, 64, 3)         0
#
#  vgg16 (Functional)          (None, 2, 2, 512)         14714688
#
#  flatten_17 (Flatten)        (None, 2048)              0
#
#  dense_34 (Dense)            (None, 2048)              4196352
#
#  batch_normalization_10 (Bat  (None, 2048)             8192
#  chNormalization)
#
#  dense_35 (Dense)            (None, 10)                20490
#
# =================================================================
# Total params: 18,939,722
# Trainable params: 18,935,626
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
filepath ="oad.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
callbacks = [checkpoint,EarlyStopping(monitor='val_accuracy', patience=100,)]
debut = time.time()
history=model.fit(train[0], train[1],
              epochs=200,
              batch_size=batch_size,
              validation_data=(test[0],test[1]),
              callbacks=callbacks,
              verbose=1)
fin = time.time()
print("Temps total : " + str(fin-debut) + "ms")
model = keras.models.load_model('oad.hdf5')
keras.models.save_model(model, base_path+'_vgg16_64.h5')
print(model.evaluate(test[0],test[1]))
# Out:
# Epoch 1/200
# 186/186 [==============================] - 15s 57ms/step - loss: 4.6514 - accuracy: 0.7745 - val_loss: 4.7400 - val_accuracy: 0.4617
# Epoch 2/200
# 186/186 [==============================] - 7s 37ms/step - loss: 1.5107 - accuracy: 0.9752 - val_loss: 1.6521 - val_accuracy: 0.7032
# Epoch 3/200
# 186/186 [==============================] - 7s 37ms/step - loss: 0.5762 - accuracy: 0.9922 - val_loss: 0.8327 - val_accuracy: 0.8729
# Epoch 4/200
# 186/186 [==============================] - 7s 38ms/step - loss: 0.4510 - accuracy: 0.9945 - val_loss: 0.7338 - val_accuracy: 0.8735
# Epoch 5/200
# 186/186 [==============================] - 7s 37ms/step - loss: 0.4238 - accuracy: 0.9941 - val_loss: 0.5899 - val_accuracy: 0.9221
# Epoch 6/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.3950 - accuracy: 0.9976 - val_loss: 0.6922 - val_accuracy: 0.8835
# Epoch 7/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3823 - accuracy: 0.9981 - val_loss: 0.5549 - val_accuracy: 0.9159
# Epoch 8/200
# 186/186 [==============================] - 7s 38ms/step - loss: 0.3732 - accuracy: 0.9983 - val_loss: 0.5360 - val_accuracy: 0.9281
# Epoch 9/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3669 - accuracy: 0.9982 - val_loss: 0.5313 - val_accuracy: 0.9241
# Epoch 10/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3598 - accuracy: 0.9997 - val_loss: 0.8811 - val_accuracy: 0.8407
# Epoch 11/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.3637 - accuracy: 0.9975 - val_loss: 0.5509 - val_accuracy: 0.9159
# Epoch 12/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3601 - accuracy: 0.9979 - val_loss: 0.5159 - val_accuracy: 0.9272
# Epoch 13/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3526 - accuracy: 0.9984 - val_loss: 0.5194 - val_accuracy: 0.9254
# Epoch 14/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.3435 - accuracy: 0.9997 - val_loss: 0.5235 - val_accuracy: 0.9250
# Epoch 15/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3415 - accuracy: 0.9994 - val_loss: 0.5619 - val_accuracy: 0.9086
# Epoch 16/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3403 - accuracy: 0.9991 - val_loss: 0.5155 - val_accuracy: 0.9273
# Epoch 17/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3374 - accuracy: 0.9996 - val_loss: 0.5194 - val_accuracy: 0.9273
# Epoch 18/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3355 - accuracy: 0.9997 - val_loss: 0.5189 - val_accuracy: 0.9269
# Epoch 19/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3442 - accuracy: 0.9977 - val_loss: 0.5454 - val_accuracy: 0.9180
# Epoch 20/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3349 - accuracy: 0.9998 - val_loss: 0.5657 - val_accuracy: 0.9179
# Epoch 21/200
# 186/186 [==============================] - 7s 36ms/step - loss: 0.3324 - accuracy: 0.9999 - val_loss: 0.5174 - val_accuracy: 0.9307
# Epoch 22/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3286 - accuracy: 0.9997 - val_loss: 0.5255 - val_accuracy: 0.9270
# Epoch 23/200
# 186/186 [==============================] - 7s 37ms/step - loss: 0.3272 - accuracy: 0.9995 - val_loss: 0.5041 - val_accuracy: 0.9317
# Epoch 24/200
# 186/186 [==============================] - 7s 39ms/step - loss: 0.3256 - accuracy: 0.9999 - val_loss: 0.4965 - val_accuracy: 0.9374
# Epoch 25/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3277 - accuracy: 0.9998 - val_loss: 0.4958 - val_accuracy: 0.9356
# Epoch 26/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3289 - accuracy: 0.9999 - val_loss: 0.4963 - val_accuracy: 0.9357
# Epoch 27/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3261 - accuracy: 0.9999 - val_loss: 0.5322 - val_accuracy: 0.9276
# Epoch 28/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3232 - accuracy: 0.9998 - val_loss: 0.5250 - val_accuracy: 0.9228
# Epoch 29/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3248 - accuracy: 0.9996 - val_loss: 0.5081 - val_accuracy: 0.9261
# Epoch 30/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3238 - accuracy: 1.0000 - val_loss: 0.5064 - val_accuracy: 0.9317
# Epoch 31/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3231 - accuracy: 0.9996 - val_loss: 0.5208 - val_accuracy: 0.9270
# Epoch 32/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3211 - accuracy: 0.9999 - val_loss: 0.5116 - val_accuracy: 0.9319
# Epoch 33/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3323 - accuracy: 0.9966 - val_loss: 0.5011 - val_accuracy: 0.9252
# Epoch 34/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3333 - accuracy: 0.9982 - val_loss: 0.5323 - val_accuracy: 0.9267
# Epoch 35/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3240 - accuracy: 0.9998 - val_loss: 0.5016 - val_accuracy: 0.9297
# Epoch 36/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3186 - accuracy: 0.9997 - val_loss: 0.5206 - val_accuracy: 0.9243
# Epoch 37/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3368 - accuracy: 0.9945 - val_loss: 0.6505 - val_accuracy: 0.8896
# Epoch 38/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3218 - accuracy: 0.9998 - val_loss: 0.5141 - val_accuracy: 0.9300
# Epoch 39/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3179 - accuracy: 0.9999 - val_loss: 0.4992 - val_accuracy: 0.9318
# Epoch 40/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3203 - accuracy: 1.0000 - val_loss: 0.5161 - val_accuracy: 0.9262
# Epoch 41/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3168 - accuracy: 0.9998 - val_loss: 0.4973 - val_accuracy: 0.9301
# Epoch 42/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3187 - accuracy: 0.9999 - val_loss: 0.5023 - val_accuracy: 0.9309
# Epoch 43/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3174 - accuracy: 0.9998 - val_loss: 0.5070 - val_accuracy: 0.9266
# Epoch 44/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3185 - accuracy: 0.9991 - val_loss: 0.7437 - val_accuracy: 0.8617
# Epoch 45/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.3178 - accuracy: 0.9999 - val_loss: 0.5090 - val_accuracy: 0.9327
# Epoch 46/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3184 - accuracy: 1.0000 - val_loss: 0.4994 - val_accuracy: 0.9305
# Epoch 47/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3164 - accuracy: 1.0000 - val_loss: 0.5015 - val_accuracy: 0.9329
# Epoch 48/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.3182 - accuracy: 0.9998 - val_loss: 0.5193 - val_accuracy: 0.9254
# Epoch 49/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3137 - accuracy: 1.0000 - val_loss: 0.4895 - val_accuracy: 0.9365
# Epoch 50/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3143 - accuracy: 1.0000 - val_loss: 0.4914 - val_accuracy: 0.9318
# Epoch 51/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.3134 - accuracy: 1.0000 - val_loss: 0.4958 - val_accuracy: 0.9277
# Epoch 52/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.3144 - accuracy: 0.9999 - val_loss: 0.4885 - val_accuracy: 0.9332
# Epoch 53/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3227 - accuracy: 0.9986 - val_loss: 0.5037 - val_accuracy: 0.9297
# Epoch 54/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3143 - accuracy: 0.9999 - val_loss: 0.4979 - val_accuracy: 0.9288
# Epoch 55/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.3217 - accuracy: 0.9978 - val_loss: 0.5150 - val_accuracy: 0.9294
# Epoch 56/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.3166 - accuracy: 0.9998 - val_loss: 0.5178 - val_accuracy: 0.9302
# Epoch 57/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.3137 - accuracy: 0.9999 - val_loss: 0.4973 - val_accuracy: 0.9278
# Epoch 58/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.3166 - accuracy: 0.9997 - val_loss: 0.5039 - val_accuracy: 0.9308
# Epoch 59/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3146 - accuracy: 0.9989 - val_loss: 0.4899 - val_accuracy: 0.9339
# Epoch 60/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3123 - accuracy: 1.0000 - val_loss: 0.4905 - val_accuracy: 0.9298
# Epoch 61/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3114 - accuracy: 1.0000 - val_loss: 0.4870 - val_accuracy: 0.9289
# Epoch 62/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3116 - accuracy: 0.9999 - val_loss: 0.5016 - val_accuracy: 0.9284
# Epoch 63/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3104 - accuracy: 1.0000 - val_loss: 0.4904 - val_accuracy: 0.9309
# Epoch 64/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.3120 - accuracy: 0.9998 - val_loss: 0.4960 - val_accuracy: 0.9315
# Epoch 65/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3084 - accuracy: 1.0000 - val_loss: 0.5057 - val_accuracy: 0.9242
# Epoch 66/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3100 - accuracy: 1.0000 - val_loss: 0.4956 - val_accuracy: 0.9312
# Epoch 67/200
# 186/186 [==============================] - 7s 37ms/step - loss: 0.3101 - accuracy: 1.0000 - val_loss: 0.5083 - val_accuracy: 0.9260
# Epoch 68/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3096 - accuracy: 0.9999 - val_loss: 0.4959 - val_accuracy: 0.9322
# Epoch 69/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3085 - accuracy: 0.9999 - val_loss: 0.4853 - val_accuracy: 0.9345
# Epoch 70/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3083 - accuracy: 0.9998 - val_loss: 0.4997 - val_accuracy: 0.9284
# Epoch 71/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.3081 - accuracy: 1.0000 - val_loss: 0.4918 - val_accuracy: 0.9306
# Epoch 72/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.3089 - accuracy: 1.0000 - val_loss: 0.4801 - val_accuracy: 0.9346
# Epoch 73/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3079 - accuracy: 1.0000 - val_loss: 0.4976 - val_accuracy: 0.9302
# Epoch 74/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3058 - accuracy: 1.0000 - val_loss: 0.4873 - val_accuracy: 0.9312
# Epoch 75/200
# 186/186 [==============================] - 7s 36ms/step - loss: 0.3065 - accuracy: 1.0000 - val_loss: 0.4916 - val_accuracy: 0.9305
# Epoch 76/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3062 - accuracy: 1.0000 - val_loss: 0.4890 - val_accuracy: 0.9346
# Epoch 77/200
# 186/186 [==============================] - 7s 36ms/step - loss: 0.3066 - accuracy: 0.9997 - val_loss: 0.4940 - val_accuracy: 0.9226
# Epoch 78/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.3048 - accuracy: 0.9999 - val_loss: 0.5082 - val_accuracy: 0.9283
# Epoch 79/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.3062 - accuracy: 0.9999 - val_loss: 0.4975 - val_accuracy: 0.9307
# Epoch 80/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.3040 - accuracy: 1.0000 - val_loss: 0.4955 - val_accuracy: 0.9284
# Epoch 81/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3038 - accuracy: 1.0000 - val_loss: 0.4938 - val_accuracy: 0.9299
# Epoch 82/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3055 - accuracy: 1.0000 - val_loss: 0.4883 - val_accuracy: 0.9305
# Epoch 83/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3084 - accuracy: 0.9983 - val_loss: 4.1658 - val_accuracy: 0.2200
# Epoch 84/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3158 - accuracy: 0.9966 - val_loss: 0.4971 - val_accuracy: 0.9318
# Epoch 85/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3081 - accuracy: 1.0000 - val_loss: 0.5065 - val_accuracy: 0.9291
# Epoch 86/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3062 - accuracy: 0.9999 - val_loss: 0.5019 - val_accuracy: 0.9282
# Epoch 87/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3040 - accuracy: 0.9996 - val_loss: 0.5021 - val_accuracy: 0.9272
# Epoch 88/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.3087 - accuracy: 0.9986 - val_loss: 0.5209 - val_accuracy: 0.9158
# Epoch 89/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3033 - accuracy: 0.9996 - val_loss: 0.4861 - val_accuracy: 0.9292
# Epoch 90/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.2993 - accuracy: 1.0000 - val_loss: 0.4978 - val_accuracy: 0.9301
# Epoch 91/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.3033 - accuracy: 0.9997 - val_loss: 0.5051 - val_accuracy: 0.9260
# Epoch 92/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.3002 - accuracy: 1.0000 - val_loss: 0.5009 - val_accuracy: 0.9298
# Epoch 93/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.2998 - accuracy: 0.9999 - val_loss: 0.5032 - val_accuracy: 0.9305
# Epoch 94/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.2991 - accuracy: 1.0000 - val_loss: 0.4943 - val_accuracy: 0.9311
# Epoch 95/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.2968 - accuracy: 0.9999 - val_loss: 0.4878 - val_accuracy: 0.9315
# Epoch 96/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.2981 - accuracy: 0.9999 - val_loss: 0.4899 - val_accuracy: 0.9257
# Epoch 97/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.3001 - accuracy: 1.0000 - val_loss: 0.4866 - val_accuracy: 0.9319
# Epoch 98/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.2969 - accuracy: 1.0000 - val_loss: 0.4964 - val_accuracy: 0.9266
# Epoch 99/200
# 186/186 [==============================] - 7s 36ms/step - loss: 0.2998 - accuracy: 0.9996 - val_loss: 0.4989 - val_accuracy: 0.9246
# Epoch 100/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.2978 - accuracy: 0.9999 - val_loss: 0.5037 - val_accuracy: 0.9272
# Epoch 101/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.2989 - accuracy: 0.9999 - val_loss: 0.5071 - val_accuracy: 0.9267
# Epoch 102/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.3168 - accuracy: 0.9958 - val_loss: 0.4969 - val_accuracy: 0.9295
# Epoch 103/200
# 186/186 [==============================] - 6s 33ms/step - loss: 0.2991 - accuracy: 0.9998 - val_loss: 0.4842 - val_accuracy: 0.9341
# Epoch 104/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.2987 - accuracy: 0.9999 - val_loss: 0.4835 - val_accuracy: 0.9331
# Epoch 105/200
# 186/186 [==============================] - 7s 36ms/step - loss: 0.2957 - accuracy: 1.0000 - val_loss: 0.4958 - val_accuracy: 0.9269
# Epoch 106/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.2959 - accuracy: 1.0000 - val_loss: 0.4939 - val_accuracy: 0.9272
# Epoch 107/200
# 186/186 [==============================] - 7s 36ms/step - loss: 0.2977 - accuracy: 1.0000 - val_loss: 0.4977 - val_accuracy: 0.9236
# Epoch 108/200
# 186/186 [==============================] - 7s 39ms/step - loss: 0.2956 - accuracy: 0.9999 - val_loss: 0.4974 - val_accuracy: 0.9250
# Epoch 109/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.2920 - accuracy: 1.0000 - val_loss: 0.4946 - val_accuracy: 0.9226
# Epoch 110/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.2937 - accuracy: 1.0000 - val_loss: 0.4858 - val_accuracy: 0.9282
# Epoch 111/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.2961 - accuracy: 1.0000 - val_loss: 0.4951 - val_accuracy: 0.9240
# Epoch 112/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.2946 - accuracy: 1.0000 - val_loss: 0.4877 - val_accuracy: 0.9290
# Epoch 113/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.2925 - accuracy: 1.0000 - val_loss: 0.4918 - val_accuracy: 0.9284
# Epoch 114/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.2926 - accuracy: 1.0000 - val_loss: 0.4884 - val_accuracy: 0.9281
# Epoch 115/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.2949 - accuracy: 0.9999 - val_loss: 0.4955 - val_accuracy: 0.9253
# Epoch 116/200
# 186/186 [==============================] - 7s 36ms/step - loss: 0.2942 - accuracy: 0.9999 - val_loss: 0.4955 - val_accuracy: 0.9264
# Epoch 117/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.2943 - accuracy: 1.0000 - val_loss: 0.5117 - val_accuracy: 0.9208
# Epoch 118/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.2912 - accuracy: 1.0000 - val_loss: 0.4968 - val_accuracy: 0.9225
# Epoch 119/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.2942 - accuracy: 1.0000 - val_loss: 0.4943 - val_accuracy: 0.9293
# Epoch 120/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.2889 - accuracy: 1.0000 - val_loss: 0.4963 - val_accuracy: 0.9282
# Epoch 121/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.2891 - accuracy: 1.0000 - val_loss: 0.4906 - val_accuracy: 0.9259
# Epoch 122/200
# 186/186 [==============================] - 6s 34ms/step - loss: 0.2917 - accuracy: 0.9998 - val_loss: 0.4812 - val_accuracy: 0.9299
# Epoch 123/200
# 186/186 [==============================] - 6s 35ms/step - loss: 0.2924 - accuracy: 0.9999 - val_loss: 0.4995 - val_accuracy: 0.9283
# Epoch 124/200
# 186/186 [==============================] - 7s 35ms/step - loss: 0.2912 - accuracy: 1.0000 - val_loss: 0.4927 - val_accuracy: 0.9255
# Temps total : 811.6063413619995ms
# 322/322 [==============================] - 19s 59ms/step - loss: 0.4957 - accuracy: 0.9389
# [0.49570220708847046, 0.9389498233795166]
